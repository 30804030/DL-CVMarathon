# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
import tensorflow as tf
print(tf.__version__)

import os
from google.colab import drive 
drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2`. This will be interpreted as: `1.x`.
#
#
# TensorFlow is already loaded. Please restart the runtime to change versions.
# 1.15.2
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# [Errno 2] No such file or directory: 'gdrive/My Drive'
# /content/gdrive/My Drive

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=50, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0073 - val_loss: 0.0024
#
# Epoch 00001: val_loss improved from inf to 0.00239, saving model to best_weights.h5
# Epoch 2/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0019 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00239 to 0.00194, saving model to best_weights.h5
# Epoch 3/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0014 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00194 to 0.00190, saving model to best_weights.h5
# Epoch 4/50
# 1712/1712 [==============================] - 13s 8ms/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00004: val_loss improved from 0.00190 to 0.00186, saving model to best_weights.h5
# Epoch 5/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00005: val_loss improved from 0.00186 to 0.00183, saving model to best_weights.h5
# Epoch 6/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0010 - val_loss: 0.0018
#
# Epoch 00006: val_loss improved from 0.00183 to 0.00178, saving model to best_weights.h5
# Epoch 7/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.6239e-04 - val_loss: 0.0017
#
# Epoch 00007: val_loss improved from 0.00178 to 0.00175, saving model to best_weights.h5
# Epoch 8/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.6777e-04 - val_loss: 0.0015
#
# Epoch 00008: val_loss improved from 0.00175 to 0.00154, saving model to best_weights.h5
# Epoch 9/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 7.0675e-04 - val_loss: 0.0015
#
# Epoch 00009: val_loss improved from 0.00154 to 0.00145, saving model to best_weights.h5
# Epoch 10/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 6.2968e-04 - val_loss: 0.0013
#
# Epoch 00010: val_loss improved from 0.00145 to 0.00125, saving model to best_weights.h5
# Epoch 11/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.5856e-04 - val_loss: 0.0012
#
# Epoch 00011: val_loss improved from 0.00125 to 0.00119, saving model to best_weights.h5
# Epoch 12/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.0463e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00119 to 0.00110, saving model to best_weights.h5
# Epoch 13/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.6497e-04 - val_loss: 0.0011
#
# Epoch 00013: val_loss improved from 0.00110 to 0.00107, saving model to best_weights.h5
# Epoch 14/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.3050e-04 - val_loss: 9.5058e-04
#
# Epoch 00014: val_loss improved from 0.00107 to 0.00095, saving model to best_weights.h5
# Epoch 15/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.0064e-04 - val_loss: 9.6447e-04
#
# Epoch 00015: val_loss did not improve from 0.00095
# Epoch 16/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.7982e-04 - val_loss: 0.0010
#
# Epoch 00016: val_loss did not improve from 0.00095
# Epoch 17/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.7281e-04 - val_loss: 9.8877e-04
#
# Epoch 00017: val_loss did not improve from 0.00095
# Epoch 18/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.4725e-04 - val_loss: 9.0312e-04
#
# Epoch 00018: val_loss improved from 0.00095 to 0.00090, saving model to best_weights.h5
# Epoch 19/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.3825e-04 - val_loss: 9.5318e-04
#
# Epoch 00019: val_loss did not improve from 0.00090
# Epoch 20/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.2049e-04 - val_loss: 9.1375e-04
#
# Epoch 00020: val_loss did not improve from 0.00090
# Epoch 21/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.2332e-04 - val_loss: 8.6837e-04
#
# Epoch 00021: val_loss improved from 0.00090 to 0.00087, saving model to best_weights.h5
# Epoch 22/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.0535e-04 - val_loss: 8.6474e-04
#
# Epoch 00022: val_loss improved from 0.00087 to 0.00086, saving model to best_weights.h5
# Epoch 23/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.9388e-04 - val_loss: 8.9814e-04
#
# Epoch 00023: val_loss did not improve from 0.00086
# Epoch 24/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.8237e-04 - val_loss: 8.1752e-04
#
# Epoch 00024: val_loss improved from 0.00086 to 0.00082, saving model to best_weights.h5
# Epoch 25/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.7424e-04 - val_loss: 8.7443e-04
#
# Epoch 00025: val_loss did not improve from 0.00082
# Epoch 26/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.7247e-04 - val_loss: 8.4297e-04
#
# Epoch 00026: val_loss did not improve from 0.00082
# Epoch 27/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.6084e-04 - val_loss: 8.0195e-04
#
# Epoch 00027: val_loss improved from 0.00082 to 0.00080, saving model to best_weights.h5
# Epoch 28/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.5966e-04 - val_loss: 8.4630e-04
#
# Epoch 00028: val_loss did not improve from 0.00080
# Epoch 29/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.5598e-04 - val_loss: 8.2030e-04
#
# Epoch 00029: val_loss did not improve from 0.00080
# Epoch 30/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.4433e-04 - val_loss: 8.2045e-04
#
# Epoch 00030: val_loss did not improve from 0.00080
# Epoch 31/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.4889e-04 - val_loss: 8.4766e-04
#
# Epoch 00031: val_loss did not improve from 0.00080
# Epoch 32/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.3460e-04 - val_loss: 8.6458e-04
#
# Epoch 00032: val_loss did not improve from 0.00080
# Epoch 33/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.3030e-04 - val_loss: 8.3637e-04
#
# Epoch 00033: val_loss did not improve from 0.00080
# Epoch 34/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.3072e-04 - val_loss: 8.5015e-04
#
# Epoch 00034: val_loss did not improve from 0.00080
# Epoch 35/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.3006e-04 - val_loss: 8.0408e-04
#
# Epoch 00035: val_loss did not improve from 0.00080
# Epoch 36/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.2189e-04 - val_loss: 7.9489e-04
#
# Epoch 00036: val_loss improved from 0.00080 to 0.00079, saving model to best_weights.h5
# Epoch 37/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.1598e-04 - val_loss: 8.0310e-04
#
# Epoch 00037: val_loss did not improve from 0.00079
# Epoch 38/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.1741e-04 - val_loss: 8.2090e-04
#
# Epoch 00038: val_loss did not improve from 0.00079
# Epoch 39/50
# 1712/1712 [==============================] - 13s 8ms/step - loss: 2.0472e-04 - val_loss: 8.4039e-04
#
# Epoch 00039: val_loss did not improve from 0.00079
# Epoch 40/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0753e-04 - val_loss: 7.8723e-04
#
# Epoch 00040: val_loss improved from 0.00079 to 0.00079, saving model to best_weights.h5
# Epoch 41/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0494e-04 - val_loss: 7.9780e-04
#
# Epoch 00041: val_loss did not improve from 0.00079
# Epoch 42/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9933e-04 - val_loss: 8.0113e-04
#
# Epoch 00042: val_loss did not improve from 0.00079
# Epoch 43/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9917e-04 - val_loss: 8.1301e-04
#
# Epoch 00043: val_loss did not improve from 0.00079
# Epoch 44/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0949e-04 - val_loss: 7.8241e-04
#
# Epoch 00044: val_loss improved from 0.00079 to 0.00078, saving model to best_weights.h5
# Epoch 45/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9285e-04 - val_loss: 8.1069e-04
#
# Epoch 00045: val_loss did not improve from 0.00078
# Epoch 46/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9005e-04 - val_loss: 7.8542e-04
#
# Epoch 00046: val_loss did not improve from 0.00078
# Epoch 47/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8777e-04 - val_loss: 7.8880e-04
#
# Epoch 00047: val_loss did not improve from 0.00078
# Epoch 48/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8304e-04 - val_loss: 7.9373e-04
#
# Epoch 00048: val_loss did not improve from 0.00078
# Epoch 49/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8561e-04 - val_loss: 8.0127e-04
#
# Epoch 00049: val_loss did not improve from 0.00078
# Epoch 50/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7659e-04 - val_loss: 7.7208e-04
#
# Epoch 00050: val_loss improved from 0.00078 to 0.00077, saving model to best_weights.h5

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
def augment_data(img, points):
  row, cols = img.shape
  new_img = np.copy(img)

  # 翻轉照片
  for i in range(96):
    for j in range(48):
      temp = img[i][j]
      new_img[i][j] = img[i][cols-j-1]
      new_img[i][cols-j-1] = temp

  new_points = np.copy(points)
  for i in range(0,30,2):
      new_points[i] = -points[i]

  # 調整對稱的 label
  new_points_temp = np.copy(new_points)
  new_points[0:2] = new_points_temp[2:4]
  new_points[2:4] = new_points_temp[0:2]
  new_points[4:6] = new_points_temp[8:10]
  new_points[6:8] = new_points_temp[10:12]
  new_points[8:10] = new_points_temp[4:6]
  new_points[10:12] = new_points_temp[6:8]
  new_points[12:14] = new_points_temp[16:18]
  new_points[14:16] = new_points_temp[18:20]
  new_points[16:18] = new_points_temp[12:14]
  new_points[18:20] = new_points_temp[14:16]
  new_points[22:24] = new_points_temp[24:26]
  new_points[24:26] = new_points_temp[22:24]
      
  return new_img, new_points

# %%
flip_img, flip_points = augment_data(imgs_train[0], points_train[0])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points) # 翻轉後的圖片

# %%
# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
hist_model_aug = model.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), aug_points_train, 
                           validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist],
                           shuffle=True, epochs=50, verbose=1)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.7005e-04 - val_loss: 7.3799e-04
#
# Epoch 00001: val_loss improved from inf to 0.00074, saving model to best_weights_augment.h5
# Epoch 2/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.4310e-04 - val_loss: 7.3548e-04
#
# Epoch 00002: val_loss improved from 0.00074 to 0.00074, saving model to best_weights_augment.h5
# Epoch 3/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.3252e-04 - val_loss: 7.2574e-04
#
# Epoch 00003: val_loss improved from 0.00074 to 0.00073, saving model to best_weights_augment.h5
# Epoch 4/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.1602e-04 - val_loss: 7.2566e-04
#
# Epoch 00004: val_loss improved from 0.00073 to 0.00073, saving model to best_weights_augment.h5
# Epoch 5/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.0838e-04 - val_loss: 7.2353e-04
#
# Epoch 00005: val_loss improved from 0.00073 to 0.00072, saving model to best_weights_augment.h5
# Epoch 6/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.0796e-04 - val_loss: 7.0574e-04
#
# Epoch 00006: val_loss improved from 0.00072 to 0.00071, saving model to best_weights_augment.h5
# Epoch 7/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.0052e-04 - val_loss: 7.0751e-04
#
# Epoch 00007: val_loss did not improve from 0.00071
# Epoch 8/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.9222e-04 - val_loss: 7.2139e-04
#
# Epoch 00008: val_loss did not improve from 0.00071
# Epoch 9/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.9015e-04 - val_loss: 6.8072e-04
#
# Epoch 00009: val_loss improved from 0.00071 to 0.00068, saving model to best_weights_augment.h5
# Epoch 10/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.8410e-04 - val_loss: 7.0104e-04
#
# Epoch 00010: val_loss did not improve from 0.00068
# Epoch 11/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.7769e-04 - val_loss: 6.9262e-04
#
# Epoch 00011: val_loss did not improve from 0.00068
# Epoch 12/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.8200e-04 - val_loss: 7.0522e-04
#
# Epoch 00012: val_loss did not improve from 0.00068
# Epoch 13/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.6854e-04 - val_loss: 6.9642e-04
#
# Epoch 00013: val_loss did not improve from 0.00068
# Epoch 14/50
# 3424/3424 [==============================] - 32s 9ms/step - loss: 1.6766e-04 - val_loss: 7.2386e-04
#
# Epoch 00014: val_loss did not improve from 0.00068
# Epoch 15/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.6912e-04 - val_loss: 6.9180e-04
#
# Epoch 00015: val_loss did not improve from 0.00068
# Epoch 16/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.5941e-04 - val_loss: 6.6524e-04
#
# Epoch 00016: val_loss improved from 0.00068 to 0.00067, saving model to best_weights_augment.h5
# Epoch 17/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.5585e-04 - val_loss: 6.9033e-04
#
# Epoch 00017: val_loss did not improve from 0.00067
# Epoch 18/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.5742e-04 - val_loss: 7.0480e-04
#
# Epoch 00018: val_loss did not improve from 0.00067
# Epoch 19/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.5378e-04 - val_loss: 6.8946e-04
#
# Epoch 00019: val_loss did not improve from 0.00067
# Epoch 20/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.5107e-04 - val_loss: 6.8231e-04
#
# Epoch 00020: val_loss did not improve from 0.00067
# Epoch 21/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.4779e-04 - val_loss: 6.9941e-04
#
# Epoch 00021: val_loss did not improve from 0.00067
# Epoch 22/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.5010e-04 - val_loss: 6.8536e-04
#
# Epoch 00022: val_loss did not improve from 0.00067
# Epoch 23/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.4554e-04 - val_loss: 6.7882e-04
#
# Epoch 00023: val_loss did not improve from 0.00067
# Epoch 24/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.3780e-04 - val_loss: 6.8271e-04
#
# Epoch 00024: val_loss did not improve from 0.00067
# Epoch 25/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.4297e-04 - val_loss: 7.2006e-04
#
# Epoch 00025: val_loss did not improve from 0.00067
# Epoch 26/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.4014e-04 - val_loss: 6.7298e-04
#
# Epoch 00026: val_loss did not improve from 0.00067
# Epoch 27/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.3641e-04 - val_loss: 6.9355e-04
#
# Epoch 00027: val_loss did not improve from 0.00067
# Epoch 28/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.3416e-04 - val_loss: 6.9579e-04
#
# Epoch 00028: val_loss did not improve from 0.00067
# Epoch 29/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.3189e-04 - val_loss: 7.2527e-04
#
# Epoch 00029: val_loss did not improve from 0.00067
# Epoch 30/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.3111e-04 - val_loss: 7.2337e-04
#
# Epoch 00030: val_loss did not improve from 0.00067
# Epoch 31/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.3120e-04 - val_loss: 6.9578e-04
#
# Epoch 00031: val_loss did not improve from 0.00067
# Epoch 32/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.2928e-04 - val_loss: 6.8889e-04
#
# Epoch 00032: val_loss did not improve from 0.00067
# Epoch 33/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.2565e-04 - val_loss: 6.9413e-04
#
# Epoch 00033: val_loss did not improve from 0.00067
# Epoch 34/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.2459e-04 - val_loss: 6.9280e-04
#
# Epoch 00034: val_loss did not improve from 0.00067
# Epoch 35/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.2210e-04 - val_loss: 6.7943e-04
#
# Epoch 00035: val_loss did not improve from 0.00067
# Epoch 36/50
# 3424/3424 [==============================] - 31s 9ms/step - loss: 1.2243e-04 - val_loss: 6.9007e-04
#
# Epoch 00036: val_loss did not improve from 0.00067
# Epoch 37/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1961e-04 - val_loss: 6.8754e-04
#
# Epoch 00037: val_loss did not improve from 0.00067
# Epoch 38/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1732e-04 - val_loss: 6.9381e-04
#
# Epoch 00038: val_loss did not improve from 0.00067
# Epoch 39/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1675e-04 - val_loss: 6.9239e-04
#
# Epoch 00039: val_loss did not improve from 0.00067
# Epoch 40/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1666e-04 - val_loss: 6.7375e-04
#
# Epoch 00040: val_loss did not improve from 0.00067
# Epoch 41/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1258e-04 - val_loss: 7.0493e-04
#
# Epoch 00041: val_loss did not improve from 0.00067
# Epoch 42/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1033e-04 - val_loss: 6.9730e-04
#
# Epoch 00042: val_loss did not improve from 0.00067
# Epoch 43/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1133e-04 - val_loss: 6.7107e-04
#
# Epoch 00043: val_loss did not improve from 0.00067
# Epoch 44/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1022e-04 - val_loss: 6.9711e-04
#
# Epoch 00044: val_loss did not improve from 0.00067
# Epoch 45/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1449e-04 - val_loss: 7.0337e-04
#
# Epoch 00045: val_loss did not improve from 0.00067
# Epoch 46/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1157e-04 - val_loss: 7.1241e-04
#
# Epoch 00046: val_loss did not improve from 0.00067
# Epoch 47/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0873e-04 - val_loss: 6.7411e-04
#
# Epoch 00047: val_loss did not improve from 0.00067
# Epoch 48/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0682e-04 - val_loss: 6.7108e-04
#
# Epoch 00048: val_loss did not improve from 0.00067
# Epoch 49/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0619e-04 - val_loss: 6.7186e-04
#
# Epoch 00049: val_loss did not improve from 0.00067
# Epoch 50/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0823e-04 - val_loss: 7.0086e-04
#
# Epoch 00050: val_loss did not improve from 0.00067

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %%
# Out:
# 2140
